# %% [markdown]
# # Fase 1: Entrenamiento — Dataset CXR (Kaggle)
#
# Este notebook se encarga de entrenar modelos de clasificación en el dataset de radiografías de tórax.

# %%
import sys
import os
sys.path.append('..')

import torch
from src.config import config
from src.models.classifiers import CovidClassifier
from src.data.transforms import get_cxr_transforms
from src.data.datasets import CXRDataset
from src.training.trainer import Trainer
from src.training.losses import FocalLoss
